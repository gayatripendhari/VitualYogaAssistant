# %%
import os
import numpy as np
from tensorflow.keras.utils import to_categorical
from keras.layers import Input, Dense
from keras.models import Model

# Initialize variables
label = []
dictionary = {}
c = 0

# Collect data from .npy files
X = None
y = None
for filename in os.listdir():
    if filename.endswith(".npy") and not filename.startswith("labels"):
        data = np.load(filename)
        if X is None:
            X = data
            y = np.full((data.shape[0], 1), filename.split('.')[0])
        else:
            X = np.concatenate((X, data))
            y = np.concatenate((y, np.full((data.shape[0], 1), filename.split('.')[0])))

        label.append(filename.split('.')[0])
        dictionary[filename.split('.')[0]] = c
        c += 1

# Convert labels to integers and then to one-hot encoding
y = np.vectorize(dictionary.get)(y)
y = to_categorical(y)

# Shuffle data
indices = np.arange(X.shape[0])
np.random.shuffle(indices)
X = X[indices]
y = y[indices]

# Define model architecture
ip = Input(shape=(X.shape[1],))
m = Dense(128, activation="tanh")(ip)
m = Dense(64, activation="tanh")(m)
op = Dense(y.shape[1], activation="softmax")(m)

model = Model(inputs=ip, outputs=op)

# Compile and train model
model.compile(optimizer='rmsprop', loss="categorical_crossentropy", metrics=['acc'])
model.fit(X, y, epochs=80)

# Save model and labels
model.save("model.h5")
np.save("labels.npy", np.array(label))
# Out:
# Epoch 1/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.6572 - loss: 0.6418
# Epoch 2/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9868 - loss: 0.2641
# Epoch 3/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9846 - loss: 0.1636
# Epoch 4/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.9753 - loss: 0.1243
# Epoch 5/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.9686 - loss: 0.0882
# Epoch 6/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9686 - loss: 0.0779
# Epoch 7/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9768 - loss: 0.0976
# Epoch 8/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9816 - loss: 0.0439
# Epoch 9/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9947 - loss: 0.0387
# Epoch 10/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9947 - loss: 0.0439
# Epoch 11/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9883 - loss: 0.0236
# Epoch 12/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9812 - loss: 0.0501
# Epoch 13/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.9846 - loss: 0.0232
# Epoch 14/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.9899 - loss: 0.0359
# Epoch 15/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9872 - loss: 0.0266
# Epoch 16/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9880 - loss: 0.0450
# Epoch 17/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9925 - loss: 0.0295
# Epoch 18/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9947 - loss: 0.0221
# Epoch 19/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9925 - loss: 0.0286
# Epoch 20/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.9947 - loss: 0.0136
# Epoch 21/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9925 - loss: 0.0181
# Epoch 22/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9947 - loss: 0.0159
# Epoch 23/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9962 - loss: 0.0140
# Epoch 24/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9973 - loss: 0.0098
# Epoch 25/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9880 - loss: 0.0416
# Epoch 26/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9880 - loss: 0.0221
# Epoch 27/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - acc: 0.9962 - loss: 0.0092
# Epoch 28/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.9973 - loss: 0.0073
# Epoch 29/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0105
# Epoch 30/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.9973 - loss: 0.0071
# Epoch 31/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.9962 - loss: 0.0236
# Epoch 32/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0114
# Epoch 33/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9880 - loss: 0.0205
# Epoch 34/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.9880 - loss: 0.0243
# Epoch 35/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9947 - loss: 0.0096
# Epoch 36/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9947 - loss: 0.0093
# Epoch 37/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9925 - loss: 0.0142
# Epoch 38/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9925 - loss: 0.0136
# Epoch 39/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.9962 - loss: 0.0058
# Epoch 40/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9962 - loss: 0.0063
# Epoch 41/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0058
# Epoch 42/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0061
# Epoch 43/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9973 - loss: 0.0031
# Epoch 44/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0064
# Epoch 45/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.9947 - loss: 0.0162
# Epoch 46/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.9973 - loss: 0.0054
# Epoch 47/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0044
# Epoch 48/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0020
# Epoch 49/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9761 - loss: 0.0597
# Epoch 50/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0024
# Epoch 51/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0016
# Epoch 52/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0034
# Epoch 53/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0032
# Epoch 54/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0033
# Epoch 55/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 1.0000 - loss: 0.0026
# Epoch 56/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0022
# Epoch 57/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 0.0029
# Epoch 58/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 1.0000 - loss: 0.0040
# Epoch 59/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.9925 - loss: 0.0164
# Epoch 60/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0013
# Epoch 61/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0016
# Epoch 62/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0017
# Epoch 63/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0011
# Epoch 64/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 0.0043
# Epoch 65/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0048
# Epoch 66/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0017
# Epoch 67/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 0.0023
# Epoch 68/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0032
# Epoch 69/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 0.0019
# Epoch 70/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 5.4491e-04
# Epoch 71/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 0.9522 - loss: 0.0890
# Epoch 72/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 7.3256e-04
# Epoch 73/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 7.0986e-04
# Epoch 74/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 9.3790e-04
# Epoch 75/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 5.2732e-04
# Epoch 76/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 1.0000 - loss: 7.7706e-04
# Epoch 77/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 1.0000 - loss: 8.3187e-04
# Epoch 78/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 1.0000 - loss: 9.0282e-04
# Epoch 79/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 4.7930e-04
# Epoch 80/80
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - acc: 1.0000 - loss: 4.7450e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
