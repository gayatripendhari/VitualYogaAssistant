# %%
# import tkinter as tk
#
# # Create the main window
# top = tk.Tk()
#
# # Set the title of the window
# top.title("Window with Background Image")
# window_width = 800
# window_height = 600
# top.geometry(f"{window_width}x{window_height}")
#
# # Load the background image
# bg_image = tk.PhotoImage(file="G:\\Code 23-24\\EmotionDetection\\img\\Diagram1.png")
#
# # Create a label with the background image
# bg_label = tk.Label(top, image=bg_image)
# bg_label.place(relwidth=1, relheight=1)  # Expand the label to cover the entire window
# #
# # # Other widgets and content can be added on top of the background image
# # # For example, you can add a button
# # button = tk.Button(top, text="Click me")
# # button.pack()
#
# # Start the Tkinter event loop
# top.mainloop()
#
from tkinter import *
from PIL import ImageTk
import subprocess
import mysql.connector
# import tkinter as tk
import os
import sys

win = Tk()
win.geometry("1500x800")

def run_main():
    # subprocess.call(["python", "test.py"])
     os.system('jupyter nbconvert --to notebook --execute finalDetection.ipynb')
    # except Exception as e:



def run_out():
     win.destroy()
    # subprocess.call(["python", "test.py"])
#      os.system('jupyter nbconvert --to notebook --execute login.ipynb')
#      os.system('jupyter nbconvert --ClearOutputPreprocessor.enabled=True --to notebook --execute ""')
    # except Exception as e:

#Define the PhotoImage Constructor by passing the image file
img= PhotoImage(file='stepsuryanamskar.png', master= win)
img_label= Label(win,image=img)

#define the position of the image
img_label.place(x=0, y=0)
button_width = 10
button_height = 2
button_login = Button(text="Start Yoga",width=button_width, height=button_height,fg="blue", bg="lightgreen", font=("Helvetica", "18"),command=lambda: run_main())
button_login.place(x=1010, y=170)
#
button_width = 10
button_height = 2 
button_register = Button(text="Log Out",width=button_width, height=button_height,fg="blue", bg="lightgreen",font=("Helvetica", "18"),command=lambda: run_out())
button_register.place(x=1010, y=270)
win.mainloop()
